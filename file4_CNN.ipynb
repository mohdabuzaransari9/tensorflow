# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##**architecture coding in cnn**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# architecture called tiny vgg ---->

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## get data

# %% [markdown]
# food101 dataset

# %% [markdown]
# mdbourke already preprocessed for us

# %%
import zipfile
# !wget https://storage.googleapis.com/ztm_tf_course/food_vision/pizza_steak.zip
# Out:
# --2025-01-02 23:15:28--  https://storage.googleapis.com/ztm_tf_course/food_vision/pizza_steak.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.250.65.123, 172.217.15.251, 172.217.0.91, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.250.65.123|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 109540975 (104M) [application/zip]
# Saving to: ‘pizza_steak.zip’
#
# pizza_steak.zip     100%[===================>] 104.47M   143MB/s    in 0.7s
#
# 2025-01-02 23:15:29 (143 MB/s) - ‘pizza_steak.zip’ saved [109540975/109540975]

# %%
#unzip

zip_ref=zipfile.ZipFile("pizza_steak.zip")
zip_ref.extractall()
zip_ref.close()

# %% [markdown]
# ## become one with the data
